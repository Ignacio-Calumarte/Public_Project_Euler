# %%
# %%html
# <p>The fraction <sup>49</sup>/<sub>98</sub> is a curious fraction, as an inexperienced mathematician in attempting to simplify it may incorrectly believe that <sup>49</sup>/<sub>98</sub> = <sup>4</sup>/<sub>8</sub>, which is correct, is obtained by cancelling the 9s.</p>
# <p>We shall consider fractions like, <sup>30</sup>/<sub>50</sub> = <sup>3</sup>/<sub>5</sub>, to be trivial examples.</p>
# <p>There are exactly four non-trivial examples of this type of fraction, less than one in value, and containing two digits in the numerator and denominator.</p>
# <p>If the product of these four fractions is given in its lowest common terms, find the value of the denominator.</p>
# Out:
# <p>The fraction <sup>49</sup>/<sub>98</sub> is a curious fraction, as an inexperienced mathematician in attempting to simplify it may incorrectly believe that <sup>49</sup>/<sub>98</sub> = <sup>4</sup>/<sub>8</sub>, which is correct, is obtained by cancelling the 9s.</p>
# <p>We shall consider fractions like, <sup>30</sup>/<sub>50</sub> = <sup>3</sup>/<sub>5</sub>, to be trivial examples.</p>
# <p>There are exactly four non-trivial examples of this type of fraction, less than one in value, and containing two digits in the numerator and denominator.</p>
# <p>If the product of these four fractions is given in its lowest common terms, find the value of the denominator.</p>

# %%
fraction_list = []
for a in range(1,10):
    for b in range(1,10):
        for c in range(1,10):
            for d in range(1,10): 
                if (c+d!=0 and a+b!=0):
                    first = float(int(str(a)+str(b)) / int(str(c)+str(d))) 
                    if first <1:
                        
                        if c!=0:
                            if b == d:
                                second = float(a/c)
                                if (first==second):
                                    print(a,b,c,d)
                            if a == d:
                                fourth = float(b/c)
                                if (first==fourth):
                                    print(a,b,c,d)
                        if d!=0:
                            if b==c:
                                third = float(a/d)
                                if (first==third):
                                    print(a,b,c,d)
                            if a==c:
                                fifth = float(b/d)
                                if (first==fifth):
                                    print(a,b,c,d)
# Out:
# 1 6 6 4
# 1 9 9 5
# 2 6 6 5
# 4 9 9 8

# %%
(1/4)*(19/95)*(26/65)*(1/2)
# Out:
# 0.010000000000000002

# %%
(0.010000000000000002).as_integer_ratio()
# Out:
# (1441151880758559, 144115188075855872)

# %%
1441151880758559/144115188075855872
# Out:
# 0.010000000000000002
