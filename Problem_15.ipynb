# %%
import math

# %%
# %%html
# <p>Starting in the top left corner of a 2×2 grid, and only being able to move to the right and down, there are exactly 6 routes to the bottom right corner.</p>
# <div class="center">
# <img src="project/images/p015.png" class="dark_img" alt="" /></div>
# <p>How many such routes are there through a 20×20 grid?</p>
# Out:
# <p>Starting in the top left corner of a 2×2 grid, and only being able to move to the right and down, there are exactly 6 routes to the bottom right corner.</p>
# <div class="center">
# <img src="project/images/p015.png" class="dark_img" alt="" /></div>
# <p>How many such routes are there through a 20×20 grid?</p>

# %% [markdown]
# First stage:
#     Choose how many initial steps in X-axis
#     Choose how many x intervals
# Second stage:
#     Choose y steps involved due to x intervals

# %%
for x in range(0,20):
    for steps in range(1,21-x):
        print('x',x,'steps',steps)
# Out:
# x 0 steps 1
# x 0 steps 2
# x 0 steps 3
# x 0 steps 4
# x 0 steps 5
# x 0 steps 6
# x 0 steps 7
# x 0 steps 8
# x 0 steps 9
# x 0 steps 10
# x 0 steps 11
# x 0 steps 12
# x 0 steps 13
# x 0 steps 14
# x 0 steps 15
# x 0 steps 16
# x 0 steps 17
# x 0 steps 18
# x 0 steps 19
# x 0 steps 20
# x 1 steps 1
# x 1 steps 2
# x 1 steps 3
# x 1 steps 4
# x 1 steps 5
# x 1 steps 6
# x 1 steps 7
# x 1 steps 8
# x 1 steps 9
# x 1 steps 10
# x 1 steps 11
# x 1 steps 12
# x 1 steps 13
# x 1 steps 14
# x 1 steps 15
# x 1 steps 16
# x 1 steps 17
# x 1 steps 18
# x 1 steps 19
# x 2 steps 1
# x 2 steps 2
# x 2 steps 3
# x 2 steps 4
# x 2 steps 5
# x 2 steps 6
# x 2 steps 7
# x 2 steps 8
# x 2 steps 9
# x 2 steps 10
# x 2 steps 11
# x 2 steps 12
# x 2 steps 13
# x 2 steps 14
# x 2 steps 15
# x 2 steps 16
# x 2 steps 17
# x 2 steps 18
# x 3 steps 1
# x 3 steps 2
# x 3 steps 3
# x 3 steps 4
# x 3 steps 5
# x 3 steps 6
# x 3 steps 7
# x 3 steps 8
# x 3 steps 9
# x 3 steps 10
# x 3 steps 11
# x 3 steps 12
# x 3 steps 13
# x 3 steps 14
# x 3 steps 15
# x 3 steps 16
# x 3 steps 17
# x 4 steps 1
# x 4 steps 2
# x 4 steps 3
# x 4 steps 4
# x 4 steps 5
# x 4 steps 6
# x 4 steps 7
# x 4 steps 8
# x 4 steps 9
# x 4 steps 10
# x 4 steps 11
# x 4 steps 12
# x 4 steps 13
# x 4 steps 14
# x 4 steps 15
# x 4 steps 16
# x 5 steps 1
# x 5 steps 2
# x 5 steps 3
# x 5 steps 4
# x 5 steps 5
# x 5 steps 6
# x 5 steps 7
# x 5 steps 8
# x 5 steps 9
# x 5 steps 10
# x 5 steps 11
# x 5 steps 12
# x 5 steps 13
# x 5 steps 14
# x 5 steps 15
# x 6 steps 1
# x 6 steps 2
# x 6 steps 3
# x 6 steps 4
# x 6 steps 5
# x 6 steps 6
# x 6 steps 7
# x 6 steps 8
# x 6 steps 9
# x 6 steps 10
# x 6 steps 11
# x 6 steps 12
# x 6 steps 13
# x 6 steps 14
# x 7 steps 1
# x 7 steps 2
# x 7 steps 3
# x 7 steps 4
# x 7 steps 5
# x 7 steps 6
# x 7 steps 7
# x 7 steps 8
# x 7 steps 9
# x 7 steps 10
# x 7 steps 11
# x 7 steps 12
# x 7 steps 13
# x 8 steps 1
# x 8 steps 2
# x 8 steps 3
# x 8 steps 4
# x 8 steps 5
# x 8 steps 6
# x 8 steps 7
# x 8 steps 8
# x 8 steps 9
# x 8 steps 10
# x 8 steps 11
# x 8 steps 12
# x 9 steps 1
# x 9 steps 2
# x 9 steps 3
# x 9 steps 4
# x 9 steps 5
# x 9 steps 6
# x 9 steps 7
# x 9 steps 8
# x 9 steps 9
# x 9 steps 10
# x 9 steps 11
# x 10 steps 1
# x 10 steps 2
# x 10 steps 3
# x 10 steps 4
# x 10 steps 5
# x 10 steps 6
# x 10 steps 7
# x 10 steps 8
# x 10 steps 9
# x 10 steps 10
# x 11 steps 1
# x 11 steps 2
# x 11 steps 3
# x 11 steps 4
# x 11 steps 5
# x 11 steps 6
# x 11 steps 7
# x 11 steps 8
# x 11 steps 9
# x 12 steps 1
# x 12 steps 2
# x 12 steps 3
# x 12 steps 4
# x 12 steps 5
# x 12 steps 6
# x 12 steps 7
# x 12 steps 8
# x 13 steps 1
# x 13 steps 2
# x 13 steps 3
# x 13 steps 4
# x 13 steps 5
# x 13 steps 6
# x 13 steps 7
# x 14 steps 1
# x 14 steps 2
# x 14 steps 3
# x 14 steps 4
# x 14 steps 5
# x 14 steps 6
# x 15 steps 1
# x 15 steps 2
# x 15 steps 3
# x 15 steps 4
# x 15 steps 5
# x 16 steps 1
# x 16 steps 2
# x 16 steps 3
# x 16 steps 4
# x 17 steps 1
# x 17 steps 2
# x 17 steps 3
# x 18 steps 1
# x 18 steps 2
# x 19 steps 1

# %%
math.comb(40,20)
# Out:
# 137846528820

# %%
total = 1
for i in range(21,41):
    total = total*i

# %%
for i in range(1,21):
    total = total/i

# %%
total
# Out:
# 137846528820.00003

# %%
(2*math.factorial(2-1))/(2**(2(2-1)))
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\ignac\AppData\Local\Temp/ipykernel_10148/747702348.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   (2*math.factorial(2-1))/(2**(2(2-1)))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10148/747702348.py in <module>
# ----> 1 (2*math.factorial(2-1))/(2**(2(2-1)))
#
# TypeError: 'int' object is not callable

# %%
(2*math.factorial(2-1))/(2**(2*(2-1)))
# Out:
# 0.5

# %%
(2**(2*(2-1)))
# Out:
# 4
