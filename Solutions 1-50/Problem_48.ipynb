# %%
# %%html
#
# <p>The series, 1<sup>1</sup> + 2<sup>2</sup> + 3<sup>3</sup> + ... + 10<sup>10</sup> = 10405071317.</p><p>Find the last ten digits of the series, 1<sup>1</sup> + 2<sup>2</sup> + 3<sup>3</sup> + ... + 1000<sup>1000</sup>.</p>
# Out:
# <p>The series, 1<sup>1</sup> + 2<sup>2</sup> + 3<sup>3</sup> + ... + 10<sup>10</sup> = 10405071317.</p><p>Find the last ten digits of the series, 1<sup>1</sup> + 2<sup>2</sup> + 3<sup>3</sup> + ... + 1000<sup>1000</sup>.</p>

# %%
sum_of_self_powers = 0

for i in range(1,1001):
    sum_of_self_powers += i**i
    
str(sum_of_self_powers)[-10:],len(str(sum_of_self_powers)[-10:])
# Out:
# ('9110846700', 10)

# %%
sum_of_self_powers
# Out:
# 10405071318

# %%
 print(str(sum([i**i for i in range(1, 1001)]))[-10:])
# Out:
# 9110846700
