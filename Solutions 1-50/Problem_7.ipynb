# %% [markdown]
# Question 7
# By listing the first six prime numbers: 2, 3, 5, 7, 11, and 13, we can see that the 6th prime is 13.
#
# What is the 10 001st prime number?

# %%
import math
import time

# %%
prime_candidate = 11
N = 0


while N < 10001:

    print(N,prime_candidate)
    for divisor in range(2,int(prime_candidate/2)):
        print(prime_candidate,divisor)
        if prime_candidate % divisor == 0:
            prime_candidate+=2
            pass
    prime_candidate+=2
    N +=1

print(N,prime_candidate)
# Out:
# 0 11
# 11 2
# 11 3
# 11 4
# 1 13
# 13 2
# 13 3
# 13 4
# 13 5
# 2 15
# 15 2
# 15 3
# 17 4
# 17 5
# 17 6
# 3 19
# 19 2
# 19 3
# 19 4
# 19 5
# 19 6
# 19 7
# 19 8
# 4 21
# 21 2
# 21 3
# 23 4
# 23 5
# 23 6
# 23 7
# 23 8
# 23 9
# 5 25
# 25 2
# 25 3
# 25 4
# 25 5
# 27 6
# 27 7
# 27 8
# 27 9
# 29 10
# 29 11
# 6 31
# 31 2
# 31 3
# 31 4
# 31 5
# 31 6
# 31 7
# 31 8
# 31 9
# 31 10
# 31 11
# 31 12
# 31 13
# 31 14
# 7 33
# 33 2
# 33 3
# 35 4
# 35 5
# 37 6
# 37 7
# 37 8
# 37 9
# 37 10
# 37 11
# 37 12
# 37 13
# 37 14
# 37 15
# 8 39
# 39 2
# 39 3
# 41 4
# 41 5
# 41 6
# 41 7
# 41 8
# 41 9
# 41 10
# 41 11
# 41 12
# 41 13
# 41 14
# 41 15
# 41 16
# 41 17
# 41 18
# 9 43
# 43 2
# 43 3
# 43 4
# 43 5
# 43 6
# 43 7
# 43 8
# 43 9
# 43 10
# 43 11
# 43 12
# 43 13
# 43 14
# 43 15
# 43 16
# 43 17
# 43 18
# 43 19
# 43 20
# 10 45
# 45 2
# 45 3
# 47 4
# 47 5
# 47 6
# 47 7
# 47 8
# 47 9
# 47 10
# 47 11
# 47 12
# 47 13
# 47 14
# 47 15
# 47 16
# 47 17
# 47 18
# 47 19
# 47 20
# 47 21
# 11 49
# 49 2
# 49 3
# 49 4
# 49 5
# ...

# %%
first_prime = 2
second_prime = 3

def find_prime(candidate):
    if candidate % 2 == 0:
        return 0
    
    for divisor in range(2,int(math.ceil(math.sqrt(candidate)))+1):
            if candidate%divisor == 0:
                return 0
    return 1

# %%
start = time.time()

N = 0
candidate = 3
while N < 10000:
#    print(N,candidate)
    N += find_prime(candidate)
    candidate+=1
    
# if N == 10001:
#     print(candidate)

print('total_time =', time.time()- start)
print(candidate-1)
# Out:
# total_time = 0.26100850105285645
# 104743

# %%
find_prime(0)
# Out:
# 0

# %%
find_prime(11)
# Out:
# 1
