# %% [markdown]
# Question 8

# %%
import numpy as np
import math

# %%
number_string ='...'

# %%
len(number_string)
# Out:
# 1000

# %%
example = '76784562873446827648'

# %%
type(example)
# Out:
# str

# %%
maximum =  0

for i in range(len(number_string)-13):
    
    substring = number_string[i:i+13]
    
    int_map = map(int,substring) 
    int_list = list(int_map)
    
    result = np.prod(int_list,dtype='int32')
    
    if result > maximum:
        maximum = result
    
print(maximum)
# Out:
# 2091059712

# %%
int_map = map(int,substring) 
int_list = list(int_map)

# %%
np.prod([1,2,3])
# Out:
# 6

# %%
substring = number_string[197:197+13]
    
int_map = map(int,substring) 
int_list = list(int_map)
int_list
# Out:
# [5, 5, 7, 6, 6, 8, 9, 6, 6, 4, 8, 9, 5]

# %%
math.prod(int_list)
# Out:
# 23514624000

# %%
np.prod(int_list,dtype = 'int32')
# Out:
# 2039787520

# %%
2**32
# Out:
# 4294967296

# %%
23514624000 % 2**32
# Out:
# 2039787520

# %%
max_sum = 0

for i in range(len(number_string) - 13):
    substring = number_string[i:i+13]
    integer_map = map(int, substring)
    integer_list = list(integer_map)
    
    if math.prod(integer_list) > max_sum:
        max_sum = math.prod(integer_list)
        
max_sum
# Out:
# 23514624000

# %%
i = 197
substring = number_string[i:i+13]
integer_map = map(int, substring)
integer_list = list(integer_map)

if math.prod(integer_list) > max_sum:
    max_sum = math.prod(integer_list)

# %%
integer_list
# Out:
# [5, 5, 7, 6, 6, 8, 9, 6, 6, 4, 8, 9, 5]

# %%
type(integer_list[0])
# Out:
# int

# %%
np.prod(integer_list, dtype = 'int64')
# Out:
# 23514624000

# %%
2**32
# Out:
# 4294967296

# %%
math.prod(integer_list)%(2**32)
# Out:
# 2039787520

# %%
np.prod(integer_list,dtype='int32')
# Out:
# 2039787520

# %%
np.prod(integer_list,dtype='int64')))
# Out:
# 11

# %%
math.prod(integer_list)%(2**32)
# Out:
# 2039787520

# %%
math.prod(integer_list)%(2**16) == np.prod(integer_list,dtype='int32')
# Out:
# False
