# %%
from IPython.core.display import display, HTML

# %%
display(HTML('<p>2<sup>15</sup> = 32768 and the sum of its digits is 3 + 2 + 7 + 6 + 8 = 26.</p><p>What is the sum of the digits of the number 2<sup>1000</sup>?</p>'))
# Out:
# <p>2<sup>15</sup> = 32768 and the sum of its digits is 3 + 2 + 7 + 6 + 8 = 26.</p><p>What is the sum of the digits of the number 2<sup>1000</sup>?</p>

# %%
number = str(2**1000)

# %%
def split(word):
    return [int(char) for char in word]

# %%
list_of_digits = split(number)

# %%
sum(list_of_digits)
# Out:
# 1366
